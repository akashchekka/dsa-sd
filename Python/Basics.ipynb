# %%
a = '3'
int(a)
# Out:
# 3

# %%
b = set()

b.add(1)
b.add(2)
b.add(3)

4 in b
# Out:
# False

# %%
hm1 = {}
hm2 = dict()

hm1[1] = 1
hm2[2] = 2

hm1[1]
hm2[2]
# Out:
# 2

# %%
arr = []

arr.append(1)
arr.append(2)
arr.append(3)

b = arr.pop()

print(b)

# %%
from collections import Counter

a = [1, 2, 3, 2, 4, 3, 2]
a = Counter(a)
for i in a.values():
    print(i)

a.most_common()[0]
# Out:
# 1
# 3
# 2
# 1
# (2, 3)

# %%
nums = [1, 2, 3, 4, 5]

nums = list(map(lambda x: -x, nums))

nums
# Out:
# [-1, -2, -3, -4, -5]
