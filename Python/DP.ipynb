# %% [markdown]
# ### Unique Paths

# %%
def unique_paths(m: int, n: int):
    row = [1] * n

    # for _ in range(m - 1):
    #     new_row = [1] * n
    #     for j in reversed(range(n - 1)):
    #         new_row[j] = new_row[j + 1] + row[j]
    #     row = new_row

    # print(row[0])

    for _ in range(m - 1):
        new_row = [1] * n

        for j in range(1, n):
            new_row[j] = new_row[j - 1] + row[j]
        row = new_row
        print(row)
    
    print(row[n - 1])

unique_paths(3, 7)
# Out:
# 28
